# %%
import numpy as np
import matplotlib.pyplot as plt

Change_m = []
Change_n = []
Change_k = []

i = 0
k = 0

with open ("/home/artem/Шаблоны/Matrix_Core/result_K_1.csv", 'r') as fileK:
    for line in fileK:
        Change_k.append(float(line.strip()))
        k = k + 1
#print (Change_k)
fileK.close()

with open ("/home/artem/Шаблоны/Matrix_Core/result_N_1.csv", 'r') as fileN:
    for line in fileN:
        Change_n.append(float(line.strip()))
#print (Change_n)
fileN.close()

with open ("/home/artem/Шаблоны/Matrix_Core/result_M_1.csv", 'r') as fileM:
    for line in fileM:
        Change_m.append(float(line.strip()))
#print (Change_m)
fileM.close()

plt.figure(figsize = (20, 10))
plt.plot(Change_k,'b')
plt.plot(Change_n,'g')
plt.plot(Change_m,'r')

plt.grid()
plt.title("Зависимость производительности от размеров матриц M, N, K")
plt.xlabel("Количество элементов по M, N, K x16")
plt.ylabel("Производительность %")
# Out:
# Text(0, 0.5, 'Производительность %')
