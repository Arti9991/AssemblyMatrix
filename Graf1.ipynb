# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

Change_m = []
Change_n = []
Change_k = []
My_ticks = []
i = 0
k = 0

with open ("/home/artem/Шаблоны/Matrix_Core_Block2/result_K_1.csv", 'r') as fileK:
    for line in fileK:
        Change_k.append(float(line.strip()))
        k = k + 1
        My_ticks.append(k * 16)
#print (Change_k)
fileK.close()

with open ("/home/artem/Шаблоны/Matrix_Core_Block2/result_N_1.csv", 'r') as fileN:
    for line in fileN:
        Change_n.append(float(line.strip()))
#print (Change_n)
fileN.close()

with open ("/home/artem/Шаблоны/Matrix_Core_Block2/result_M_1.csv", 'r') as fileM:
    for line in fileM:
        Change_m.append(float(line.strip()))
#print (Change_m)
fileM.close()


fig , ax = plt.subplots(figsize = (20, 10))

plt.plot(My_ticks,Change_k,'b', label = 'k')
plt.plot(My_ticks,Change_n,'g', label = 'n')
plt.plot(My_ticks,Change_m,'r', label = 'm')
plt.legend()

plt.xlim([0, k*16])
ax.xaxis.set_major_locator(ticker.MultipleLocator(256))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(64))

ax.yaxis.set_major_locator(ticker.MultipleLocator(10))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(5))

plt.grid()
plt.title("Зависимость производительности от размеров матриц M, N, K")
plt.xlabel("Количество элементов по M, N, K x16")
plt.ylabel("Производительность %")
# Out:
# Text(0, 0.5, 'Производительность %')
